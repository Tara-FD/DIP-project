# %% [markdown]
# <a href="https://colab.research.google.com/github/Tara-FD/DIP-project/blob/master/ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mohammad2682/Covid19-Dataset
# Out:
# Cloning into 'Covid19-Dataset'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 2523 (delta 6), reused 0 (delta 0), pack-reused 2502
# Receiving objects: 100% (2523/2523), 229.95 MiB | 12.38 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# Checking out files: 100% (4965/4965), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import VGG16
from keras.applications import ResNet50
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
disease_types=['COVID', 'non-COVID']
data_dir = 'Covid19-Dataset/Covid-19-Dataset/train'
train_dir = os.path.join(data_dir)

# %% [markdown]
# ## Creating Dataframe

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# Randomize the Order
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) 
train.head()
# Out:
#                              File  DiseaseID Disease Type
# 0   non-COVID/Non-Covid (129).png          1    non-COVID
# 1           COVID/Covid (484).png          0        COVID
# 2   non-COVID/Non-Covid (662).png          1    non-COVID
# 3           COVID/Covid (418).png          0        COVID
# 4  non-COVID/Non-Covid (1077).png          1    non-COVID

# %% [markdown]
# ## Image Display

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
plot_defects('COVID', 5, 5)

# %%
plot_defects('non-COVID', 5, 5)

# %% [markdown]
# ## Image Read

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))

# %% [markdown]
# ## Image Resize

# %%
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ## Training Images

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2000it [00:06, 295.59it/s]
# Train Shape: (2000, 64, 64, 3)

# %% [markdown]
# ## Converting Labels to Categorical

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %% [markdown]
# ## Train Test Splitting

# %%
BATCH_SIZE = 64 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
EPOCHS = 50
SIZE = 64
N_ch = 3

# %% [markdown]
# ## ResNet50 Model

# %%
def build_net():
    net = ResNet50(weights='imagenet', include_top=False)
    #input layer
    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    #pre-trained network
    x = net(x)
    #classifier
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    #output layer
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    #model
    model = Model(input,output)
    

    model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# ## Data Augmentation and Fitting Model

# %%
model = build_net()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# resnet50 (Model)             multiple                  23587712
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2048)              8192
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 24,122,070
# Trainable params: 24,064,342
# Non-trainable params: 57,728
# _________________________________________________________________
# Epoch 1/50
#  - 20s - loss: 0.9552 - accuracy: 0.6450 - val_loss: 3.6629 - val_accuracy: 0.5075
#
# Epoch 00001: val_loss improved from inf to 3.66287, saving model to model.h5
# Epoch 2/50
#  - 3s - loss: 0.6162 - accuracy: 0.7525 - val_loss: 5.8850 - val_accuracy: 0.5075
#
# Epoch 00002: val_loss did not improve from 3.66287
# Epoch 3/50
#  - 4s - loss: 0.5099 - accuracy: 0.7994 - val_loss: 1.4340 - val_accuracy: 0.5075
#
# Epoch 00003: val_loss improved from 3.66287 to 1.43403, saving model to model.h5
# Epoch 4/50
#  - 4s - loss: 0.3936 - accuracy: 0.8294 - val_loss: 0.7542 - val_accuracy: 0.5075
#
# Epoch 00004: val_loss improved from 1.43403 to 0.75420, saving model to model.h5
# Epoch 5/50
#  - 4s - loss: 0.3863 - accuracy: 0.8331 - val_loss: 0.9199 - val_accuracy: 0.5075
#
# Epoch 00005: val_loss did not improve from 0.75420
# Epoch 6/50
#  - 4s - loss: 0.4364 - accuracy: 0.8175 - val_loss: 2.8583 - val_accuracy: 0.5075
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.5.
#
# Epoch 00006: val_loss did not improve from 0.75420
# Epoch 7/50
#  - 4s - loss: 0.3345 - accuracy: 0.8656 - val_loss: 1.3054 - val_accuracy: 0.5075
#
# Epoch 00007: val_loss did not improve from 0.75420
# Epoch 8/50
#  - 4s - loss: 0.2926 - accuracy: 0.8838 - val_loss: 0.9572 - val_accuracy: 0.5075
#
# Epoch 00008: val_loss did not improve from 0.75420
# Epoch 9/50
#  - 4s - loss: 0.2923 - accuracy: 0.8850 - val_loss: 0.8735 - val_accuracy: 0.5075
#
# Epoch 00009: val_loss did not improve from 0.75420
# Epoch 10/50
#  - 4s - loss: 0.3057 - accuracy: 0.8850 - val_loss: 0.7107 - val_accuracy: 0.5075
#
# Epoch 00010: val_loss improved from 0.75420 to 0.71071, saving model to model.h5
# Epoch 11/50
#  - 4s - loss: 0.2975 - accuracy: 0.8712 - val_loss: 0.9960 - val_accuracy: 0.5075
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.25.
#
# Epoch 00011: val_loss did not improve from 0.71071
# Epoch 12/50
#  - 4s - loss: 0.2687 - accuracy: 0.8888 - val_loss: 0.9352 - val_accuracy: 0.5075
#
# Epoch 00012: val_loss did not improve from 0.71071
# Epoch 13/50
#  - 4s - loss: 0.2700 - accuracy: 0.8888 - val_loss: 0.8973 - val_accuracy: 0.5075
#
# Epoch 00013: val_loss did not improve from 0.71071
# Epoch 14/50
#  - 4s - loss: 0.2596 - accuracy: 0.8925 - val_loss: 0.7269 - val_accuracy: 0.5075
#
# Epoch 00014: val_loss did not improve from 0.71071
# Epoch 15/50
#  - 4s - loss: 0.2520 - accuracy: 0.8900 - val_loss: 0.7042 - val_accuracy: 0.4875
#
# Epoch 00015: val_loss improved from 0.71071 to 0.70420, saving model to model.h5
# Epoch 16/50
#  - 4s - loss: 0.2583 - accuracy: 0.8881 - val_loss: 0.7203 - val_accuracy: 0.5075
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.125.
#
# Epoch 00016: val_loss did not improve from 0.70420
# Epoch 17/50
#  - 4s - loss: 0.2590 - accuracy: 0.8975 - val_loss: 0.6862 - val_accuracy: 0.4950
#
# Epoch 00017: val_loss improved from 0.70420 to 0.68622, saving model to model.h5
# Epoch 18/50
#  - 4s - loss: 0.2311 - accuracy: 0.9050 - val_loss: 0.6813 - val_accuracy: 0.5300
#
# Epoch 00018: val_loss improved from 0.68622 to 0.68134, saving model to model.h5
# Epoch 19/50
#  - 4s - loss: 0.2288 - accuracy: 0.9075 - val_loss: 0.6665 - val_accuracy: 0.5775
#
# Epoch 00019: val_loss improved from 0.68134 to 0.66654, saving model to model.h5
# Epoch 20/50
#  - 4s - loss: 0.2153 - accuracy: 0.9069 - val_loss: 0.6900 - val_accuracy: 0.4875
#
# Epoch 00020: val_loss did not improve from 0.66654
# Epoch 21/50
#  - 4s - loss: 0.2244 - accuracy: 0.9031 - val_loss: 0.6543 - val_accuracy: 0.5625
#
# Epoch 00021: val_loss improved from 0.66654 to 0.65432, saving model to model.h5
# Epoch 22/50
#  - 4s - loss: 0.2063 - accuracy: 0.9100 - val_loss: 0.7042 - val_accuracy: 0.4875
#
# Epoch 00022: val_loss did not improve from 0.65432
# Epoch 23/50
#  - 4s - loss: 0.2005 - accuracy: 0.9156 - val_loss: 0.6933 - val_accuracy: 0.5175
#
# Epoch 00023: val_loss did not improve from 0.65432
# Epoch 24/50
#  - 4s - loss: 0.1989 - accuracy: 0.9094 - val_loss: 0.6692 - val_accuracy: 0.5325
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0625.
#
# Epoch 00024: val_loss did not improve from 0.65432
# Epoch 25/50
#  - 4s - loss: 0.1850 - accuracy: 0.9181 - val_loss: 0.6852 - val_accuracy: 0.4650
#
# Epoch 00025: val_loss did not improve from 0.65432
# Epoch 26/50
#  - 4s - loss: 0.1909 - accuracy: 0.9169 - val_loss: 0.6858 - val_accuracy: 0.4350
#
# Epoch 00026: val_loss did not improve from 0.65432
# Epoch 27/50
#  - 4s - loss: 0.1870 - accuracy: 0.9225 - val_loss: 0.6959 - val_accuracy: 0.5150
#
# Epoch 00027: val_loss did not improve from 0.65432
# Epoch 28/50
#  - 4s - loss: 0.1926 - accuracy: 0.9212 - val_loss: 0.6912 - val_accuracy: 0.4925
#
# Epoch 00028: val_loss did not improve from 0.65432
# Epoch 29/50
#  - 4s - loss: 0.1947 - accuracy: 0.9181 - val_loss: 0.6933 - val_accuracy: 0.4950
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.03125.
#
# Epoch 00029: val_loss did not improve from 0.65432
# Epoch 30/50
#  - 4s - loss: 0.1600 - accuracy: 0.9269 - val_loss: 0.7050 - val_accuracy: 0.5150
#
# Epoch 00030: val_loss did not improve from 0.65432
# Epoch 31/50
#  - 4s - loss: 0.2011 - accuracy: 0.9162 - val_loss: 0.7114 - val_accuracy: 0.5175
#
# Epoch 00031: val_loss did not improve from 0.65432
# Epoch 32/50
#  - 4s - loss: 0.1770 - accuracy: 0.9144 - val_loss: 0.7232 - val_accuracy: 0.5200
#
# Epoch 00032: val_loss did not improve from 0.65432
# Epoch 33/50
#  - 4s - loss: 0.1835 - accuracy: 0.9200 - val_loss: 0.7251 - val_accuracy: 0.5425
#
# Epoch 00033: val_loss did not improve from 0.65432
# Epoch 34/50
#  - 4s - loss: 0.1777 - accuracy: 0.9250 - val_loss: 0.6961 - val_accuracy: 0.5550
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.015625.
#
# Epoch 00034: val_loss did not improve from 0.65432
# Epoch 35/50
#  - 4s - loss: 0.1723 - accuracy: 0.9300 - val_loss: 0.7026 - val_accuracy: 0.5525
#
# Epoch 00035: val_loss did not improve from 0.65432
# Epoch 36/50
#  - 4s - loss: 0.1805 - accuracy: 0.9281 - val_loss: 0.7189 - val_accuracy: 0.5700
#
# Epoch 00036: val_loss did not improve from 0.65432
# Epoch 37/50
#  - 4s - loss: 0.1702 - accuracy: 0.9300 - val_loss: 0.7403 - val_accuracy: 0.5650
#
# Epoch 00037: val_loss did not improve from 0.65432
# Epoch 38/50
#  - 4s - loss: 0.2057 - accuracy: 0.9187 - val_loss: 0.7600 - val_accuracy: 0.5700
#
# Epoch 00038: val_loss did not improve from 0.65432
# Epoch 39/50
#  - 4s - loss: 0.1779 - accuracy: 0.9225 - val_loss: 0.7860 - val_accuracy: 0.5750
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0078125.
#
# Epoch 00039: val_loss did not improve from 0.65432
# Epoch 40/50
#  - 4s - loss: 0.1856 - accuracy: 0.9206 - val_loss: 0.7933 - val_accuracy: 0.6000
#
# Epoch 00040: val_loss did not improve from 0.65432
# Epoch 41/50
#  - 4s - loss: 0.1673 - accuracy: 0.9269 - val_loss: 0.8017 - val_accuracy: 0.6175
#
# Epoch 00041: val_loss did not improve from 0.65432
# Epoch 42/50
#  - 4s - loss: 0.1592 - accuracy: 0.9362 - val_loss: 0.7996 - val_accuracy: 0.6700
#
# Epoch 00042: val_loss did not improve from 0.65432
# Epoch 43/50
#  - 4s - loss: 0.1608 - accuracy: 0.9319 - val_loss: 0.7726 - val_accuracy: 0.7100
#
# Epoch 00043: val_loss did not improve from 0.65432
# Epoch 44/50
#  - 4s - loss: 0.1558 - accuracy: 0.9425 - val_loss: 0.7523 - val_accuracy: 0.7250
#
# Epoch 00044: val_loss did not improve from 0.65432
# Epoch 45/50
#  - 4s - loss: 0.1748 - accuracy: 0.9256 - val_loss: 0.6977 - val_accuracy: 0.7725
#
# Epoch 00045: val_loss did not improve from 0.65432
# Epoch 46/50
#  - 4s - loss: 0.1688 - accuracy: 0.9331 - val_loss: 0.6150 - val_accuracy: 0.8125
#
# Epoch 00046: val_loss improved from 0.65432 to 0.61501, saving model to model.h5
# Epoch 47/50
#  - 4s - loss: 0.1637 - accuracy: 0.9369 - val_loss: 0.5486 - val_accuracy: 0.8250
#
# Epoch 00047: val_loss improved from 0.61501 to 0.54859, saving model to model.h5
# Epoch 48/50
#  - 3s - loss: 0.1898 - accuracy: 0.9225 - val_loss: 0.4801 - val_accuracy: 0.8500
#
# Epoch 00048: val_loss improved from 0.54859 to 0.48011, saving model to model.h5
# Epoch 49/50
#  - 4s - loss: 0.1794 - accuracy: 0.9306 - val_loss: 0.4140 - val_accuracy: 0.8800
#
# Epoch 00049: val_loss improved from 0.48011 to 0.41395, saving model to model.h5
# Epoch 50/50
#  - 4s - loss: 0.1756 - accuracy: 0.9287 - val_loss: 0.3415 - val_accuracy: 0.8875
#
# Epoch 00050: val_loss improved from 0.41395 to 0.34152, saving model to model.h5

# %% [markdown]
# ## Final Loss and Accuracy

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 400/400 [==============================] - 0s 821us/step
# Final Loss: 0.34151979625225065, Final Accuracy: 0.887499988079071

# %% [markdown]
# ## Confusion Matrix

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %% [markdown]
# ## Accuracy and Loss Curve

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
yhat_probs = model.predict(X_val)

yhat_classes = np.round(model.predict(X_val))

# %%
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]
Y_val2 = Y_val[:,0]

# %% [markdown]
# ## Evaluation

# %%
accuracy = accuracy_score(Y_val2, yhat_classes)
print('Accuracy: %0.2f' % accuracy)

precision = precision_score(Y_val2, yhat_classes)
print('Precision: %0.2f' % precision)

recall = recall_score(Y_val2, yhat_classes)
print('Recall: %0.2f' % recall)

f1 = f1_score(Y_val2, yhat_classes)
print('F1 score: %0.2f' % f1)
# Out:
# Accuracy: 0.89
# Precision: 0.97
# Recall: 0.79
# F1 score: 0.87
