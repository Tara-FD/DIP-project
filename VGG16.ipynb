# %% [markdown]
# <a href="https://colab.research.google.com/github/Tara-FD/DIP-project/blob/master/VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mohammad2682/Covid19-Dataset
# Out:
# fatal: destination path 'Covid19-Dataset' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import VGG16
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score

# %%
disease_types=['COVID', 'non-COVID']
data_dir = 'Covid19-Dataset/Covid-19-Dataset/train'
train_dir = os.path.join(data_dir)

# %% [markdown]
# ## Creating Dataframe

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# Randomize the Order
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0  non-COVID/Non-Covid (138).png          1    non-COVID
# 1          COVID/Covid (735).png          0        COVID
# 2  non-COVID/Non-Covid (679).png          1    non-COVID
# 3         COVID/Covid (1161).png          0        COVID
# 4  non-COVID/Non-Covid (707).png          1    non-COVID

# %% [markdown]
# ## Image Display

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
plot_defects('COVID', 5, 5)

# %%
plot_defects('non-COVID', 5, 5)

# %% [markdown]
# ## Image Read

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))

# %% [markdown]
# ## Image Resize

# %%
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ## Training Images

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2000it [00:06, 328.47it/s]
# Train Shape: (2000, 64, 64, 3)

# %% [markdown]
# ## Converting Labels to Categorical

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %% [markdown]
# ## Train Test Splitting

# %%
BATCH_SIZE = 64 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
EPOCHS = 50
SIZE = 64
N_ch = 3

# %% [markdown]
# ## VGG16 Model

# %%
def build_net():
    net = VGG16(weights='imagenet', include_top=False)
    #input layer
    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    #pre-trained network
    x = net(x)
    #classifier
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    #output layer
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    #model
    model = Model(input,output)
    
    #optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    #optimizer = 'adadelta'
    model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# ## Data Augmentation and Fitting Model

# %%
model = build_net()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# vgg16 (Model)                multiple                  14714688
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 14,849,686
# Trainable params: 14,848,150
# Non-trainable params: 1,536
# _________________________________________________________________
# Epoch 1/50
#  - 3s - loss: 1.1528 - accuracy: 0.5281 - val_loss: 2.6172 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 2.61717, saving model to model.h5
# Epoch 2/50
#  - 2s - loss: 0.8957 - accuracy: 0.5944 - val_loss: 7.2554 - val_accuracy: 0.4925
#
# Epoch 00002: val_loss did not improve from 2.61717
# Epoch 3/50
#  - 2s - loss: 0.8021 - accuracy: 0.6194 - val_loss: 0.6883 - val_accuracy: 0.6425
#
# Epoch 00003: val_loss improved from 2.61717 to 0.68828, saving model to model.h5
# Epoch 4/50
#  - 2s - loss: 0.8979 - accuracy: 0.5412 - val_loss: 23.2850 - val_accuracy: 0.5075
#
# Epoch 00004: val_loss did not improve from 0.68828
# Epoch 5/50
#  - 2s - loss: 0.8001 - accuracy: 0.5825 - val_loss: 0.6873 - val_accuracy: 0.6525
#
# Epoch 00005: val_loss improved from 0.68828 to 0.68728, saving model to model.h5
# Epoch 6/50
#  - 2s - loss: 0.7947 - accuracy: 0.5906 - val_loss: 0.6794 - val_accuracy: 0.5925
#
# Epoch 00006: val_loss improved from 0.68728 to 0.67944, saving model to model.h5
# Epoch 7/50
#  - 2s - loss: 0.7439 - accuracy: 0.5919 - val_loss: 0.7466 - val_accuracy: 0.5300
#
# Epoch 00007: val_loss did not improve from 0.67944
# Epoch 8/50
#  - 2s - loss: 0.7395 - accuracy: 0.5981 - val_loss: 0.6750 - val_accuracy: 0.4925
#
# Epoch 00008: val_loss improved from 0.67944 to 0.67505, saving model to model.h5
# Epoch 9/50
#  - 2s - loss: 0.7016 - accuracy: 0.6187 - val_loss: 2.8594 - val_accuracy: 0.5075
#
# Epoch 00009: val_loss did not improve from 0.67505
# Epoch 10/50
#  - 2s - loss: 0.6687 - accuracy: 0.6269 - val_loss: 3.2538 - val_accuracy: 0.5075
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.5.
#
# Epoch 00010: val_loss did not improve from 0.67505
# Epoch 11/50
#  - 2s - loss: 0.5750 - accuracy: 0.7294 - val_loss: 0.4815 - val_accuracy: 0.7625
#
# Epoch 00011: val_loss improved from 0.67505 to 0.48150, saving model to model.h5
# Epoch 12/50
#  - 2s - loss: 0.4878 - accuracy: 0.7844 - val_loss: 1.6994 - val_accuracy: 0.5225
#
# Epoch 00012: val_loss did not improve from 0.48150
# Epoch 13/50
#  - 2s - loss: 0.4551 - accuracy: 0.8075 - val_loss: 3.8010 - val_accuracy: 0.5075
#
# Epoch 00013: val_loss did not improve from 0.48150
# Epoch 14/50
#  - 2s - loss: 0.4552 - accuracy: 0.8119 - val_loss: 8.0485 - val_accuracy: 0.5075
#
# Epoch 00014: val_loss did not improve from 0.48150
# Epoch 15/50
#  - 2s - loss: 0.4446 - accuracy: 0.8256 - val_loss: 8.1029 - val_accuracy: 0.5075
#
# Epoch 00015: val_loss did not improve from 0.48150
# Epoch 16/50
#  - 2s - loss: 0.5392 - accuracy: 0.7513 - val_loss: 5.7348 - val_accuracy: 0.4925
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.25.
#
# Epoch 00016: val_loss did not improve from 0.48150
# Epoch 17/50
#  - 2s - loss: 0.3733 - accuracy: 0.8550 - val_loss: 1.2162 - val_accuracy: 0.6175
#
# Epoch 00017: val_loss did not improve from 0.48150
# Epoch 18/50
#  - 2s - loss: 0.3716 - accuracy: 0.8512 - val_loss: 0.5340 - val_accuracy: 0.7850
#
# Epoch 00018: val_loss did not improve from 0.48150
# Epoch 19/50
#  - 2s - loss: 0.3514 - accuracy: 0.8750 - val_loss: 1.2016 - val_accuracy: 0.6375
#
# Epoch 00019: val_loss did not improve from 0.48150
# Epoch 20/50
#  - 2s - loss: 0.3475 - accuracy: 0.8800 - val_loss: 2.0649 - val_accuracy: 0.5775
#
# Epoch 00020: val_loss did not improve from 0.48150
# Epoch 21/50
#  - 2s - loss: 0.3448 - accuracy: 0.8731 - val_loss: 5.4094 - val_accuracy: 0.5075
#
# Epoch 00021: val_loss did not improve from 0.48150
# Epoch 22/50
#  - 2s - loss: 0.3454 - accuracy: 0.8744 - val_loss: 0.3078 - val_accuracy: 0.8825
#
# Epoch 00022: val_loss improved from 0.48150 to 0.30784, saving model to model.h5
# Epoch 23/50
#  - 2s - loss: 0.3431 - accuracy: 0.8725 - val_loss: 0.2358 - val_accuracy: 0.9100
#
# Epoch 00023: val_loss improved from 0.30784 to 0.23583, saving model to model.h5
# Epoch 24/50
#  - 2s - loss: 0.3374 - accuracy: 0.8662 - val_loss: 1.8281 - val_accuracy: 0.5800
#
# Epoch 00024: val_loss did not improve from 0.23583
# Epoch 25/50
#  - 2s - loss: 0.3027 - accuracy: 0.8875 - val_loss: 2.2667 - val_accuracy: 0.5650
#
# Epoch 00025: val_loss did not improve from 0.23583
# Epoch 26/50
#  - 2s - loss: 0.3212 - accuracy: 0.8763 - val_loss: 1.4752 - val_accuracy: 0.6375
#
# Epoch 00026: val_loss did not improve from 0.23583
# Epoch 27/50
#  - 2s - loss: 0.3076 - accuracy: 0.8856 - val_loss: 3.4821 - val_accuracy: 0.5300
#
# Epoch 00027: val_loss did not improve from 0.23583
# Epoch 28/50
#  - 2s - loss: 0.3122 - accuracy: 0.8687 - val_loss: 2.0947 - val_accuracy: 0.5000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.125.
#
# Epoch 00028: val_loss did not improve from 0.23583
# Epoch 29/50
#  - 2s - loss: 0.2948 - accuracy: 0.8950 - val_loss: 1.2353 - val_accuracy: 0.6250
#
# Epoch 00029: val_loss did not improve from 0.23583
# Epoch 30/50
#  - 2s - loss: 0.2875 - accuracy: 0.9019 - val_loss: 0.2071 - val_accuracy: 0.9200
#
# Epoch 00030: val_loss improved from 0.23583 to 0.20713, saving model to model.h5
# Epoch 31/50
#  - 2s - loss: 0.2858 - accuracy: 0.8975 - val_loss: 0.2470 - val_accuracy: 0.8900
#
# Epoch 00031: val_loss did not improve from 0.20713
# Epoch 32/50
#  - 2s - loss: 0.2663 - accuracy: 0.9075 - val_loss: 2.8897 - val_accuracy: 0.5425
#
# Epoch 00032: val_loss did not improve from 0.20713
# Epoch 33/50
#  - 2s - loss: 0.2819 - accuracy: 0.8950 - val_loss: 2.6057 - val_accuracy: 0.5625
#
# Epoch 00033: val_loss did not improve from 0.20713
# Epoch 34/50
#  - 2s - loss: 0.2788 - accuracy: 0.9006 - val_loss: 0.5286 - val_accuracy: 0.8000
#
# Epoch 00034: val_loss did not improve from 0.20713
# Epoch 35/50
#  - 2s - loss: 0.2767 - accuracy: 0.8950 - val_loss: 1.4639 - val_accuracy: 0.6250
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0625.
#
# Epoch 00035: val_loss did not improve from 0.20713
# Epoch 36/50
#  - 2s - loss: 0.2605 - accuracy: 0.9019 - val_loss: 0.7451 - val_accuracy: 0.7475
#
# Epoch 00036: val_loss did not improve from 0.20713
# Epoch 37/50
#  - 2s - loss: 0.2643 - accuracy: 0.9006 - val_loss: 0.8147 - val_accuracy: 0.7525
#
# Epoch 00037: val_loss did not improve from 0.20713
# Epoch 38/50
#  - 2s - loss: 0.2713 - accuracy: 0.8994 - val_loss: 0.3640 - val_accuracy: 0.8175
#
# Epoch 00038: val_loss did not improve from 0.20713
# Epoch 39/50
#  - 2s - loss: 0.2638 - accuracy: 0.9013 - val_loss: 0.2544 - val_accuracy: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.20713
# Epoch 40/50
#  - 2s - loss: 0.2677 - accuracy: 0.9038 - val_loss: 0.2197 - val_accuracy: 0.9175
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.03125.
#
# Epoch 00040: val_loss did not improve from 0.20713
# Epoch 41/50
#  - 2s - loss: 0.2660 - accuracy: 0.8981 - val_loss: 0.3525 - val_accuracy: 0.8675
#
# Epoch 00041: val_loss did not improve from 0.20713
# Epoch 42/50
#  - 2s - loss: 0.2529 - accuracy: 0.9112 - val_loss: 1.0270 - val_accuracy: 0.7000
#
# Epoch 00042: val_loss did not improve from 0.20713
# Epoch 43/50
#  - 2s - loss: 0.2595 - accuracy: 0.8994 - val_loss: 0.2593 - val_accuracy: 0.9025
#
# Epoch 00043: val_loss did not improve from 0.20713
# Epoch 44/50
#  - 2s - loss: 0.2627 - accuracy: 0.9044 - val_loss: 0.2036 - val_accuracy: 0.9375
#
# Epoch 00044: val_loss improved from 0.20713 to 0.20355, saving model to model.h5
# Epoch 45/50
#  - 2s - loss: 0.2498 - accuracy: 0.9062 - val_loss: 0.1922 - val_accuracy: 0.9350
#
# Epoch 00045: val_loss improved from 0.20355 to 0.19223, saving model to model.h5
# Epoch 46/50
#  - 2s - loss: 0.2512 - accuracy: 0.9112 - val_loss: 0.4999 - val_accuracy: 0.8200
#
# Epoch 00046: val_loss did not improve from 0.19223
# Epoch 47/50
#  - 2s - loss: 0.2616 - accuracy: 0.9031 - val_loss: 0.4429 - val_accuracy: 0.7950
#
# Epoch 00047: val_loss did not improve from 0.19223
# Epoch 48/50
#  - 2s - loss: 0.2404 - accuracy: 0.9081 - val_loss: 0.1933 - val_accuracy: 0.9300
#
# Epoch 00048: val_loss did not improve from 0.19223
# Epoch 49/50
#  - 2s - loss: 0.2583 - accuracy: 0.9044 - val_loss: 0.3771 - val_accuracy: 0.8700
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.015625.
#
# Epoch 00049: val_loss did not improve from 0.19223
# Epoch 50/50
#  - 2s - loss: 0.2498 - accuracy: 0.9056 - val_loss: 0.3392 - val_accuracy: 0.8775
#
# Epoch 00050: val_loss did not improve from 0.19223

# %% [markdown]
# ## Final Loss and Accuracy

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 400/400 [==============================] - 0s 728us/step
# Final Loss: 0.3392292793467641, Final Accuracy: 0.8774999976158142

# %% [markdown]
# ## Confusion Matrix

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %% [markdown]
# ## Accuracy and Loss Curve

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
yhat_probs = model.predict(X_val)

yhat_classes = np.round(model.predict(X_val))

# %%
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]
Y_val2 = Y_val[:,0]

# %% [markdown]
# ## Evaluation

# %%
accuracy = accuracy_score(Y_val2, yhat_classes)
print('Accuracy: %f' % accuracy)

precision = precision_score(Y_val2, yhat_classes)
print('Precision: %f' % precision)

recall = recall_score(Y_val2, yhat_classes)
print('Recall: %f' % recall)

f1 = f1_score(Y_val2, yhat_classes)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.877500
# Precision: 0.986842
# Recall: 0.761421
# F1 score: 0.859599
